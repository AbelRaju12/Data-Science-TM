# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sample_space = 52
spades = 13
p_spades = round(spades/sample_space, 4)
p_spades
# Out:
# 0.25

# %%
p_facecards = round(12/sample_space, 4)
p_facecards
# Out:
# 0.2308

# %%
aces = 4
p_ace  = round(aces/sample_space, 4)
p_ace
# Out:
# 0.0769

# %%
air = pd.read_csv('Airbnb_Open_Data.csv')
air.head()
# Out:
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_12640\2524591296.py:1: DtypeWarning: Columns (25) have mixed types. Specify dtype option on import or set low_memory=False.
#   air = pd.read_csv('Airbnb_Open_Data.csv')
#         id                                              NAME      host id  \
# 0  1001254                Clean & quiet apt home by the park  80014485718
# 1  1002102                             Skylit Midtown Castle  52335172823
# 2  1002403               THE VILLAGE OF HARLEM....NEW YORK !  78829239556
# 3  1002755                                               NaN  85098326012
# 4  1003689  Entire Apt: Spacious Studio/Loft by central park  92037596077
#
#   host_identity_verified host name neighbourhood group neighbourhood  \
# 0            unconfirmed  Madaline            Brooklyn    Kensington
# 1               verified     Jenna           Manhattan       Midtown
# 2                    NaN     Elise           Manhattan        Harlem
# ...

# %%
air['neighbourhood'].value_counts()
# Out:
# Bedford-Stuyvesant        7937
# Williamsburg              7775
# Harlem                    5466
# Bushwick                  4982
# Hell's Kitchen            3965
#                           ...
# Rossville                    3
# Lighthouse Hill              3
# Fort Wadsworth               2
# Glen Oaks                    2
# Chelsea, Staten Island       1
# Name: neighbourhood, Length: 224, dtype: int64

# %%
harlem = air.apply(lambda x: True if x['neighbourhood'] == 'Harlem' else False, axis = 1)

# %%
har = len(harlem[harlem == True].index)

# %%
p_har = round(har/10234, 3)
p_har
# Out:
# 0.534

# %%
#conditional probability
data = pd.DataFrame({'count':air.groupby(['neighbourhood group', 'neighbourhood']).size()}).reset_index()
data
# Out:
#     neighbourhood group neighbourhood  count
# 0                 Bronx      Allerton     97
# 1                 Bronx    Baychester     29
# 2                 Bronx       Belmont     45
# 3                 Bronx     Bronxdale     48
# 4                 Bronx   Castle Hill     22
# ..                  ...           ...    ...
# 221       Staten Island   Westerleigh      5
# 222       Staten Island   Willowbrook      3
# 223       Staten Island       Woodrow      3
# 224             brookln   South Slope      1
# 225            manhatan       Chelsea      1
#
# [226 rows x 3 columns]

# %%
data[data['neighbourhood group'] == 'Bronx']
# Out:
#    neighbourhood group       neighbourhood  count
# 0                Bronx            Allerton     97
# 1                Bronx          Baychester     29
# 2                Bronx             Belmont     45
# 3                Bronx           Bronxdale     48
# 4                Bronx         Castle Hill     22
# 5                Bronx         City Island     41
# 6                Bronx   Claremont Village     59
# 7                Bronx        Clason Point     50
# 8                Bronx          Co-op City      5
# 9                Bronx           Concourse    123
# 10               Bronx   Concourse Village     76
# 11               Bronx     East Morrisania     21
# 12               Bronx         Eastchester     28
# 13               Bronx            Edenwald     35
# 14               Bronx           Fieldston     25
# 15               Bronx             Fordham    153
# 16               Bronx          Highbridge     67
# 17               Bronx         Hunts Point     53
# ...

# %%
ss = data[data['neighbourhood group'] == 'Bronx']['count'].sum()
ss
# Out:
# 2712

# %%
p_apt  = round(1000 / ss, 3)
p_apt
# Out:
# 0.369

# %%
air['neighbourhood group'].value_counts()
air.shape
# Out:
# (102599, 26)

# %%
p_apt = round(ss / 102559, 3)
p_apt
# Out:
# 0.026
